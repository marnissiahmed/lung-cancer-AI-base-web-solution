# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Concatenate,UpSampling2D,Dropout,Input,Add,Conv2DTranspose
from tensorflow.keras.metrics import Precision,Recall
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import backend as k
from tensorflow.keras.metrics import Accuracy,Precision , Recall
from sklearn.model_selection import train_test_split
import numpy as np 
import matplotlib.pyplot as plt
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
def fcn(input_size):
    input_scan = Input(input_size)
    conv1 = Conv2D(32, (3, 3), padding="same", activation="relu")(input_scan)
    conv1 = Conv2D(32, (3, 3), padding="same", activation="relu")(conv1)
    pool1 = MaxPooling2D((2, 2))(conv1)
    conv2 = Conv2D(64, (3, 3), padding="same", activation="relu")(pool1)
    conv2 = Conv2D(64, (3, 3), padding="same", activation="relu")(conv2)
    pool2 = MaxPooling2D((2, 2))(conv2)
    conv3 = Conv2D(128, (3, 3), padding="same", activation="relu")(pool2)
    conv3 = Conv2D(128, (3, 3), padding="same", activation="relu")(conv3)
    pool3 = MaxPooling2D((2, 2))(conv3)
    conv4 = Conv2D(256, (3, 3), padding="same", activation="relu")(pool3)
    conv4 = Conv2D(256, (3, 3), padding="same", activation="relu")(conv4)
    pool4 = MaxPooling2D((2, 2))(conv4)
    conv5 = Conv2D(512, (3, 3), padding="same", activation="relu")(pool4)
    conv6 =  Conv2D(128, (1, 1), padding="same")(conv5)
    conv7 =  Conv2D(64, (1, 1), padding="same")(pool4)
    merge1 = Concatenate()([conv7, conv6])
    up2 =  UpSampling2D((2, 2))(merge1)
    conv8 =  Conv2D(64, (1, 1), padding="same")(pool3)
    merge2 = Concatenate()([conv8,up2])
    up3 = UpSampling2D((8, 8))(merge2)
    out_layer = Conv2D(1, (1, 1), padding="same", activation="sigmoid")(up3)
    model = tf.keras.Model(input_scan, out_layer, name='fcn')
    return model

# %%
fcn = fcn((512,512,1))

# %%
fcn.summary()
# Out:
# Model: "fcn"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 32  320         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 32  9248        ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 32  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 64  36928       ['conv2d_2[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 64  0          ['conv2d_3[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 12  73856       ['max_pooling2d_1[0][0]']
#                                 8)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 12  147584      ['conv2d_4[0][0]']
#                                 8)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 128)  0          ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 256)  590080      ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 256)  0          ['conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 512)  1180160     ['max_pooling2d_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 64)   16448       ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 128)  65664       ['conv2d_8[0][0]']
#
#  concatenate (Concatenate)      (None, 32, 32, 192)  0           ['conv2d_10[0][0]',
#                                                                   'conv2d_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 64)   8256        ['max_pooling2d_2[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 64, 64, 192)  0           ['concatenate[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_11[0][0]',
#                                                                   'up_sampling2d[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 512, 512, 25  0          ['concatenate_1[0][0]']
#                                 6)
#
#  conv2d_12 (Conv2D)             (None, 512, 512, 1)  257         ['up_sampling2d_1[0][0]']
#
# ==================================================================================================
# Total params: 2,442,465
# Trainable params: 2,442,465
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(fcn, show_shapes=True, rankdir='TB',
to_file='model_cifar10.png')

# %%
X1 = np.load("/kaggle/input/data12/X1.npy")
X0 = np.load("/kaggle/input/data12/X0.npy")
Y1 = np.load("/kaggle/input/data12/mask1.npy")
Y0 = np.load("/kaggle/input/data12/mask0.npy")

# %%
X1.shape
# Out:
# (1153, 512, 512, 1)

# %%
X = np.concatenate((X1,X0),axis=0)
Y = np.concatenate((Y1,Y0),axis=0)

# %%
X1=0
X0=0
Y1 =0
Y0=0

# %%
X=X/255
Y=Y/255

# %%
Xtrain,Xtest,Ytrain,Ytest = train_test_split(X,Y,test_size =0.20,random_state=48)

# %%
from tensorflow.keras.layers import Flatten
def iou_score(y_true, y_pred):
    intersection = 0 
    y_true_f = Flatten()(y_true)
    y_pred_f = Flatten()(y_pred)
    intersection =  (2.*(y_true_f * y_pred_f) + tf.keras.backend.epsilon())
    union = (y_true_f + y_pred_f + tf.keras.backend.epsilon())
    return (intersection/union)

# %%
fcn.compile(optimizer = Adam(learning_rate=0.0001),loss = "BinaryCrossentropy",metrics=[iou_score])

# %%
X=0
Y=0

# %%
hist = fcn.fit(Xtrain,Ytrain,epochs=50,batch_size=8,validation_data=(Xtest,Ytest))
# Out:
# Epoch 1/50
# 144/144 [==============================] - 40s 194ms/step - loss: 0.0672 - iou_score: 0.3458 - val_loss: 0.0047 - val_iou_score: 0.0851
# Epoch 2/50
# 144/144 [==============================] - 26s 182ms/step - loss: 0.0038 - iou_score: 0.1944 - val_loss: 0.0038 - val_iou_score: 0.2361
# Epoch 3/50
# 144/144 [==============================] - 26s 182ms/step - loss: 0.0036 - iou_score: 0.2473 - val_loss: 0.0037 - val_iou_score: 0.2576
# Epoch 4/50
# 144/144 [==============================] - 26s 182ms/step - loss: 0.0036 - iou_score: 0.2698 - val_loss: 0.0037 - val_iou_score: 0.2827
# Epoch 5/50
# 144/144 [==============================] - 26s 182ms/step - loss: 0.0035 - iou_score: 0.2905 - val_loss: 0.0036 - val_iou_score: 0.2945
# Epoch 6/50
# 144/144 [==============================] - 26s 182ms/step - loss: 0.0035 - iou_score: 0.3150 - val_loss: 0.0036 - val_iou_score: 0.3119
# Epoch 7/50
# 144/144 [==============================] - 26s 182ms/step - loss: 0.0034 - iou_score: 0.3312 - val_loss: 0.0034 - val_iou_score: 0.3367
# Epoch 8/50
# 144/144 [==============================] - 26s 182ms/step - loss: 0.0032 - iou_score: 0.3469 - val_loss: 0.0032 - val_iou_score: 0.3753
# Epoch 9/50
# 144/144 [==============================] - 26s 182ms/step - loss: 0.0031 - iou_score: 0.3536 - val_loss: 0.0030 - val_iou_score: 0.3788
# Epoch 10/50
# 144/144 [==============================] - 26s 182ms/step - loss: 0.0030 - iou_score: 0.3682 - val_loss: 0.0029 - val_iou_score: 0.3505
# Epoch 11/50
# 144/144 [==============================] - 26s 182ms/step - loss: 0.0029 - iou_score: 0.3709 - val_loss: 0.0029 - val_iou_score: 0.3228
# Epoch 12/50
# 144/144 [==============================] - 26s 182ms/step - loss: 0.0028 - iou_score: 0.3522 - val_loss: 0.0027 - val_iou_score: 0.3403
# Epoch 13/50
# 144/144 [==============================] - 26s 182ms/step - loss: 0.0027 - iou_score: 0.3789 - val_loss: 0.0025 - val_iou_score: 0.3578
# Epoch 14/50
# 144/144 [==============================] - 26s 182ms/step - loss: 0.0026 - iou_score: 0.3772 - val_loss: 0.0025 - val_iou_score: 0.3655
# Epoch 15/50
# 144/144 [==============================] - 26s 182ms/step - loss: 0.0024 - iou_score: 0.3802 - val_loss: 0.0027 - val_iou_score: 0.3417
# Epoch 16/50
# 144/144 [==============================] - 26s 182ms/step - loss: 0.0023 - iou_score: 0.3873 - val_loss: 0.0021 - val_iou_score: 0.3561
# Epoch 17/50
# 144/144 [==============================] - 26s 182ms/step - loss: 0.0022 - iou_score: 0.3726 - val_loss: 0.0019 - val_iou_score: 0.4093
# Epoch 18/50
# 144/144 [==============================] - 26s 182ms/step - loss: 0.0021 - iou_score: 0.3892 - val_loss: 0.0018 - val_iou_score: 0.3767
# Epoch 19/50
# 144/144 [==============================] - 26s 182ms/step - loss: 0.0019 - iou_score: 0.4169 - val_loss: 0.0019 - val_iou_score: 0.3695
# Epoch 20/50
# 144/144 [==============================] - 26s 182ms/step - loss: 0.0018 - iou_score: 0.3880 - val_loss: 0.0016 - val_iou_score: 0.3952
# Epoch 21/50
# 144/144 [==============================] - 26s 182ms/step - loss: 0.0017 - iou_score: 0.4219 - val_loss: 0.0015 - val_iou_score: 0.4138
# Epoch 22/50
# 144/144 [==============================] - 26s 182ms/step - loss: 0.0016 - iou_score: 0.4319 - val_loss: 0.0015 - val_iou_score: 0.3646
# Epoch 23/50
# 144/144 [==============================] - 26s 182ms/step - loss: 0.0016 - iou_score: 0.3858 - val_loss: 0.0014 - val_iou_score: 0.3624
# Epoch 24/50
# 144/144 [==============================] - 26s 182ms/step - loss: 0.0014 - iou_score: 0.4001 - val_loss: 0.0014 - val_iou_score: 0.4548
# Epoch 25/50
# 144/144 [==============================] - 26s 181ms/step - loss: 0.0014 - iou_score: 0.4257 - val_loss: 0.0013 - val_iou_score: 0.4268
# Epoch 26/50
# 144/144 [==============================] - 26s 181ms/step - loss: 0.0014 - iou_score: 0.4385 - val_loss: 0.0016 - val_iou_score: 0.3554
# Epoch 27/50
# 144/144 [==============================] - 26s 181ms/step - loss: 0.0013 - iou_score: 0.4179 - val_loss: 0.0013 - val_iou_score: 0.4834
# Epoch 28/50
# 144/144 [==============================] - 26s 181ms/step - loss: 0.0013 - iou_score: 0.4572 - val_loss: 0.0013 - val_iou_score: 0.4207
# Epoch 29/50
# 144/144 [==============================] - 26s 181ms/step - loss: 0.0012 - iou_score: 0.4468 - val_loss: 0.0014 - val_iou_score: 0.4943
# Epoch 30/50
# 144/144 [==============================] - 26s 181ms/step - loss: 0.0012 - iou_score: 0.4654 - val_loss: 0.0013 - val_iou_score: 0.4638
# Epoch 31/50
# 144/144 [==============================] - 26s 181ms/step - loss: 0.0012 - iou_score: 0.4653 - val_loss: 0.0014 - val_iou_score: 0.5310
# Epoch 32/50
# 144/144 [==============================] - 26s 182ms/step - loss: 0.0012 - iou_score: 0.4205 - val_loss: 0.0012 - val_iou_score: 0.4825
# Epoch 33/50
# 144/144 [==============================] - 26s 181ms/step - loss: 0.0011 - iou_score: 0.4746 - val_loss: 0.0013 - val_iou_score: 0.4938
# Epoch 34/50
# 144/144 [==============================] - 26s 181ms/step - loss: 0.0010 - iou_score: 0.4905 - val_loss: 0.0012 - val_iou_score: 0.4364
# Epoch 35/50
# 144/144 [==============================] - 26s 181ms/step - loss: 0.0010 - iou_score: 0.5083 - val_loss: 0.0013 - val_iou_score: 0.5102
# Epoch 36/50
# 144/144 [==============================] - 26s 181ms/step - loss: 0.0010 - iou_score: 0.4993 - val_loss: 0.0015 - val_iou_score: 0.5556
# Epoch 37/50
# 144/144 [==============================] - 26s 181ms/step - loss: 9.8026e-04 - iou_score: 0.5168 - val_loss: 0.0013 - val_iou_score: 0.5452
# Epoch 38/50
# 144/144 [==============================] - 26s 181ms/step - loss: 9.9695e-04 - iou_score: 0.4681 - val_loss: 0.0012 - val_iou_score: 0.4839
# Epoch 39/50
# 144/144 [==============================] - 26s 181ms/step - loss: 9.3014e-04 - iou_score: 0.5281 - val_loss: 0.0012 - val_iou_score: 0.5303
# Epoch 40/50
# 144/144 [==============================] - 26s 181ms/step - loss: 9.7495e-04 - iou_score: 0.5304 - val_loss: 0.0012 - val_iou_score: 0.5386
# Epoch 41/50
# 144/144 [==============================] - 26s 181ms/step - loss: 9.1713e-04 - iou_score: 0.5398 - val_loss: 0.0012 - val_iou_score: 0.5680
# Epoch 42/50
# 144/144 [==============================] - 26s 181ms/step - loss: 8.6928e-04 - iou_score: 0.5550 - val_loss: 0.0013 - val_iou_score: 0.6173
# Epoch 43/50
# 144/144 [==============================] - 26s 181ms/step - loss: 8.6855e-04 - iou_score: 0.5728 - val_loss: 0.0015 - val_iou_score: 0.5907
# Epoch 44/50
# 144/144 [==============================] - 26s 181ms/step - loss: 8.3964e-04 - iou_score: 0.5812 - val_loss: 0.0013 - val_iou_score: 0.6586
# Epoch 45/50
# 144/144 [==============================] - 26s 181ms/step - loss: 8.3602e-04 - iou_score: 0.6019 - val_loss: 0.0012 - val_iou_score: 0.5440
# Epoch 46/50
# 144/144 [==============================] - 26s 181ms/step - loss: 7.9252e-04 - iou_score: 0.6022 - val_loss: 0.0011 - val_iou_score: 0.5745
# Epoch 47/50
# 144/144 [==============================] - 26s 181ms/step - loss: 7.6864e-04 - iou_score: 0.6116 - val_loss: 0.0015 - val_iou_score: 0.6264
# Epoch 48/50
# 144/144 [==============================] - 26s 181ms/step - loss: 8.0817e-04 - iou_score: 0.6207 - val_loss: 0.0012 - val_iou_score: 0.5690
# Epoch 49/50
# 144/144 [==============================] - 26s 181ms/step - loss: 7.4315e-04 - iou_score: 0.6269 - val_loss: 0.0012 - val_iou_score: 0.6118
# Epoch 50/50
# 144/144 [==============================] - 26s 181ms/step - loss: 7.2055e-04 - iou_score: 0.6478 - val_loss: 0.0012 - val_iou_score: 0.6136

# %%
import matplotlib.pyplot as plt
plt.figure(1, figsize=(8, 8))
plt.suptitle("performance") 
plt.subplot(2, 1, 1)
plt.plot(np.arange(0, 50), hist.history["loss"], label="Perte apprentissage")
plt.plot(np.arange(0, 50), hist.history["val_loss"], label="Perte validation")
plt.xlabel("Epochs")
plt.ylabel("Perte") 
plt.subplot(2, 1, 2)
plt.plot(np.arange(0, 50), hist.history["iou_score"], label="iou_score apprentissage")
plt.plot(np.arange(0, 50), hist.history["val_iou_score"], label="iou_score validation") 
plt.xlabel("Epochs") 
plt.ylabel("Intersection over Union")


plt.legend()

# %%
fcn.evaluate(Xtest,Ytest,batch_size=8)
# Out:
# 36/36 [==============================] - 2s 59ms/step - loss: 0.0012 - iou_score: 0.6136
# [0.001246687606908381, 0.6135594844818115]

# %%
y_1 = fcn.predict(Xtest[3].reshape((1,512,512, 1)))
# Out:
# 1/1 [==============================] - 0s 446ms/step

# %%
y_1 = y_1.reshape((512,512))
plt.imshow(y_1,cmap="gray")

# %%
y_1.max()
# Out:
# 0.1409061

# %%
y_1 = np.where(y_1>0.5,1,0)
plt.imshow(y_1,cmap="gray")

# %%
norm_img = Xtest[3].reshape((512,512))
img = norm_img * 255

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(20, 20))
ax1.imshow(img,cmap="gray" )
ax1.set_title('Original nodule')
ax2.imshow(img,cmap='gray')
ax2.set_title('fcn prediction ')
ax2.contour(y_1.reshape((512,512)), levels=[0.4], colors='r', linewidths=2)
ax1.contour(Ytest[3].reshape((512,512)), levels=[0.4], colors='r', linewidths=2)
plt.show()
# Out:
# /tmp/ipykernel_35/2819400389.py:6: UserWarning: No contour levels were found within the data range.
#   ax2.contour(y_1.reshape((512,512)), levels=[0.4], colors='r', linewidths=2)

# %%
fcn.save("fcn.h5")
